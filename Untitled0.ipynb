# %% [markdown]
# <a href="https://colab.research.google.com/github/AnandBanoth2004/ML_Project_task/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('Gujrat 2022-23.newlyedited2.csv')
df = df.set_index('DateTime')
df.index = pd.to_datetime(df.index)

# %%
df.head()
# Out:
#                          Date   Time  Power_MW
# DateTime
# 2022-04-01 00:00:00  4-1-2022  00:00     90.93
# 2022-04-01 00:15:00  4-1-2022  00:15     94.97
# 2022-04-01 00:30:00  4-1-2022  00:30    108.82
# 2022-04-01 00:45:00  4-1-2022  00:45    112.58
# 2022-04-01 01:00:00  4-1-2022  01:00    105.05

# %%
df
# Out:
#                           Date   Time  Power_MW
# DateTime
# 2022-04-01 00:00:00   4-1-2022  00:00     90.93
# 2022-04-01 00:15:00   4-1-2022  00:15     94.97
# 2022-04-01 00:30:00   4-1-2022  00:30    108.82
# 2022-04-01 00:45:00   4-1-2022  00:45    112.58
# 2022-04-01 01:00:00   4-1-2022  01:00    105.05
# ...                        ...    ...       ...
# 2023-03-31 22:45:00  3-31-2023  22:45    120.56
# 2023-03-31 23:00:00  3-31-2023  23:00    120.05
# 2023-03-31 23:15:00  3-31-2023  23:15    110.98
# 2023-03-31 23:30:00  3-31-2023  23:30    102.69
# 2023-03-31 23:45:00  3-31-2023  23:45    107.03
#
# [35040 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Power_MW'], dtype='object')

# %%
plot1=df.plot(style='.',figsize=(15,5),color='blue',title='POWER IN MW')
plt.show()

# %%
train = df.loc[df.index < '01-01-2023']
test = df.loc[df.index >= '01-01-2023']
fig, ax = plt.subplots(figsize=(15,5))
train.plot(ax=ax, label='Train Set',title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('01-01-2023',color='black',ls='--')
ax.legend(['Train Set', 'Test Set'])
plt.show()

# %%
df.loc[(df.index > '04-01-2022') & (df.index < '04-08-2022')].plot(figsize=(15,5),title='Week of Data')
plt.show()

# %%
def create_features(df):
    df=df.copy()

    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    return df

df = create_features(df)

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.boxplot(data=df, x='hour', y='Power_MW')
ax.set_title('MW by HOUR')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.boxplot(data=df, x='month', y='Power_MW',palette='Blues')
ax.set_title('MW by Month')
plt.show()
# Out:
# <ipython-input-15-2d50b861a53a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='month', y='Power_MW',palette='Blues')

# %%
#create our model

# %%
train = create_features(train)
test = create_features(test)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Power_MW', 'hour', 'dayofweek', 'quarter', 'month',
#        'year', 'dayofyear'],
#       dtype='object')

# %%
FEATURES = ['hour', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear']
TARGET = 'Power_MW'

# %%
X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(n_estimators=1000, early_stopping_rounds=50,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:14.71254	validation_1-rmse:16.68489
# [100]	validation_0-rmse:10.01564	validation_1-rmse:12.85998
# [200]	validation_0-rmse:8.94075	validation_1-rmse:11.83429
# [300]	validation_0-rmse:8.48510	validation_1-rmse:11.44225
# [400]	validation_0-rmse:8.18477	validation_1-rmse:11.37743
# [416]	validation_0-rmse:8.15057	validation_1-rmse:11.38176
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
# ...

# %%
#feature importance

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])

# %%
fi.sort_values('importance').plot(kind='barh',title='Feature Importance')
plt.show()

# %%
#forecast on test

# %%
test['predictions'] = reg.predict(X_test)

# %%
df=df.merge(test[['predictions']], how='left', left_index=True, right_index=True)

# %%
ax = df[['Power_MW']].plot(figsize=(15,5))
df['predictions'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Dat and Predictions')
plt.show()

# %%
ax = df.loc[(df.index > '01-01-2023') & (df.index < '01-08-2023')]['Power_MW'] \
     .plot(figsize=(15,5), title='week of data')
df.loc[(df.index > '01-01-2023') & (df.index < '01-08-2023')]['predictions'] \
     .plot(style='.')
plt.legend(['Truth Data','Predictions'])
plt.show()

# %%
score = np.sqrt(mean_squared_error(test['Power_MW'], test['predictions']))
print(f'RMSE Score on the Test set:{score:0.2f}')
# Out:
# RMSE Score on the Test set:11.37

# %%
#calculate error

# %%
test['error'] = np.abs(test[TARGET] - test['predictions'])

# %%
test['date'] = test.index.date

# %%
test.groupby(['date'])['error'].mean().sort_values(ascending=False).head(10)
# Out:
# date
# 2023-03-30    20.958928
# 2023-03-06    15.296242
# 2023-03-05    14.301777
# 2023-03-24    14.102637
# 2023-03-31    14.003209
# 2023-02-11    13.738942
# 2023-03-23    12.636984
# 2023-03-28    12.028641
# 2023-02-17    11.425079
# 2023-02-26    11.119483
# Name: error, dtype: float64

# %%
#next steps

# %%
df['Power_MW'].plot(kind='hist', bins=500)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.query('Power_MW <60').plot(figsize=(15,5), style='.')
# Out:
# <Axes: xlabel='DateTime'>

# %%
#time series cross validation

# %%
from sklearn.model_selection import TimeSeriesSplit
tss = TimeSeriesSplit(n_splits=3, test_size=24*365*1, gap=24)
df = df.sort_index()

# %%
fig, axs = plt.subplots(3,1,figsize=(15,15))

fold = 0
for train_idx, val_idx in tss.split(df):
  train = df.iloc[train_idx]
  test = df.iloc[val_idx]
  train['Power_MW'].plot(ax=axs[fold],
                         label='Training_Set',
                         title=f'Data Train/Test Split fold {fold}')
  test['Power_MW'].plot(ax=axs[fold],
                        label='Test Set')
  axs[fold].axvline(test.index.min(), color='black',ls='--')
  fold += 1
plt.show()

# %%
#forecasting harizon explained

# %%
df['Power_MW']
# Out:
# DateTime
# 2022-04-01 00:00:00     90.93
# 2022-04-01 00:15:00     94.97
# 2022-04-01 00:30:00    108.82
# 2022-04-01 00:45:00    112.58
# 2022-04-01 01:00:00    105.05
#                         ...
# 2023-03-31 22:45:00    120.56
# 2023-03-31 23:00:00    120.05
# 2023-03-31 23:15:00    110.98
# 2023-03-31 23:30:00    102.69
# 2023-03-31 23:45:00    107.03
# Name: Power_MW, Length: 35040, dtype: float64

# %%
def add_lags(df):
  target_map = df['Power_MW'].to_dict()
  df['lag1'] = (df.index - pd.Timedelta('364 days')).map(target_map)
  df['lag2'] = (df.index - pd.Timedelta('728 days')).map(target_map)
  df['lag3'] = (df.index - pd.Timedelta('1092 days')).map(target_map)
  return df

# %%
df = add_lags(df)

# %%
df.head()
# Out:
#                          Date   Time  Power_MW  hour  dayofweek  quarter  \
# DateTime
# 2022-04-01 00:00:00  4-1-2022  00:00     90.93     0          4        2
# 2022-04-01 00:15:00  4-1-2022  00:15     94.97     0          4        2
# 2022-04-01 00:30:00  4-1-2022  00:30    108.82     0          4        2
# 2022-04-01 00:45:00  4-1-2022  00:45    112.58     0          4        2
# 2022-04-01 01:00:00  4-1-2022  01:00    105.05     1          4        2
#
#                      month  year  dayofyear  prediction_x  prediction_y  \
# DateTime
# 2022-04-01 00:00:00      4  2022         91           NaN           NaN
# 2022-04-01 00:15:00      4  2022         91           NaN           NaN
# 2022-04-01 00:30:00      4  2022         91           NaN           NaN
# 2022-04-01 00:45:00      4  2022         91           NaN           NaN
# 2022-04-01 01:00:00      4  2022         91           NaN           NaN
#
#                      predictions  lag1  lag2  lag3
# DateTime
# ...

# %%
df.tail()
# Out:
#                           Date   Time  Power_MW  hour  dayofweek  quarter  \
# DateTime
# 2023-03-31 22:45:00  3-31-2023  22:45    120.56    22          4        1
# 2023-03-31 23:00:00  3-31-2023  23:00    120.05    23          4        1
# 2023-03-31 23:15:00  3-31-2023  23:15    110.98    23          4        1
# 2023-03-31 23:30:00  3-31-2023  23:30    102.69    23          4        1
# 2023-03-31 23:45:00  3-31-2023  23:45    107.03    23          4        1
#
#                      month  year  dayofyear  prediction_x  prediction_y  \
# DateTime
# 2023-03-31 22:45:00      3  2023         90    106.713478    106.713478
# 2023-03-31 23:00:00      3  2023         90    108.058334    108.058334
# 2023-03-31 23:15:00      3  2023         90    108.058334    108.058334
# 2023-03-31 23:30:00      3  2023         90    108.058334    108.058334
# 2023-03-31 23:45:00      3  2023         90    108.058334    108.058334
#
#                      predictions    lag1  lag2  lag3
# DateTime
# ...

# %%
tss = TimeSeriesSplit(n_splits=3, test_size=24*365*1, gap=24)
df = df.sort_index()

fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(df):
  train = df.iloc[train_idx]
  test = df.iloc[val_idx]

  train = create_features(train)
  test = create_features(test)

  FEATURES = ['hour', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear', 'lag1', 'lag2', 'lag3']
  TARGET = 'Power_MW'

  X_train = train[FEATURES]
  y_train = train[TARGET]

  X_test = test[FEATURES]
  y_test = test[TARGET]

  reg =xgb.XGBRegressor(base_score=0.5, booster='gbtree',
                        n_estimators=1000,
                        early_stopping_rounds=50,
                        objective='reg:linear',
                        max_depth=3,
                        learning_rate=0.01)
  reg.fit(X_train, y_train,
          eval_set=[(X_train, y_train), (X_test, y_test)],
          verbose=100)
  y_pred = reg.predict(X_test)
  preds.append(y_pred)
  score = np.sqrt(mean_squared_error(y_test, y_pred))
  scores.append(score)
# Out:
# [0]	validation_0-rmse:99.60873	validation_1-rmse:97.74804
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [10:08:47] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [100]	validation_0-rmse:37.49861	validation_1-rmse:35.56094
# [200]	validation_0-rmse:16.05876	validation_1-rmse:14.39825
# [300]	validation_0-rmse:10.01176	validation_1-rmse:10.09754
# [400]	validation_0-rmse:8.78273	validation_1-rmse:9.89054
# [403]	validation_0-rmse:8.76879	validation_1-rmse:9.89570
# [0]	validation_0-rmse:98.70223	validation_1-rmse:101.75825
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [10:08:50] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [100]	validation_0-rmse:37.22882	validation_1-rmse:40.38606
# ...

# %%
print(f'Scorre across folds {np.mean(scores):0.4f}')
print(f'Fold scores:{scores}')
# Out:
# Scorre across folds 10.6940
# Fold scores:[9.839556872909304, 10.833802565327444, 11.408628355753292]

# %%
#predicting the future

# %%
df = create_features(df)

FEATURES = ['hour', 'dayofweek', 'quarter', 'month', 'year', 'dayofyear', 'lag1', 'lag2', 'lag3']
TARGET = 'Power_MW'

X_all = df[FEATURES]
y_all = df[TARGET]

reg =xgb.XGBRegressor(base_score=0.5, booster='gbtree',
                        n_estimators=600,
                        objective='reg:linear',
                        max_depth=3,
                        learning_rate=0.01)
reg.fit(X_all, y_all,
        eval_set=[(X_all, y_all)],
        verbose=100)
# Out:
# [0]	validation_0-rmse:101.06377
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [10:23:00] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [100]	validation_0-rmse:38.14755
# [200]	validation_0-rmse:16.63576
# [300]	validation_0-rmse:10.74640
# [400]	validation_0-rmse:9.50523
# [500]	validation_0-rmse:9.23951
# [599]	validation_0-rmse:9.13432
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
# ...

# %%
#create future dataframe

# %%
df.index.max()
# Out:
# Timestamp('2023-03-31 23:45:00')

# %%
future = pd.date_range('2023-03-31','2024-03-31', freq='15Min')
future_df = pd.DataFrame(index = future)
future_df['isFuture'] = True
df['isFuture'] = False
df_and_future = pd.concat([df,future_df])

# %%
df_and_future
# Out:
#                          Date   Time  Power_MW  hour  dayofweek  quarter  \
# 2022-04-01 00:00:00  4-1-2022  00:00     90.93   0.0        4.0      2.0
# 2022-04-01 00:15:00  4-1-2022  00:15     94.97   0.0        4.0      2.0
# 2022-04-01 00:30:00  4-1-2022  00:30    108.82   0.0        4.0      2.0
# 2022-04-01 00:45:00  4-1-2022  00:45    112.58   0.0        4.0      2.0
# 2022-04-01 01:00:00  4-1-2022  01:00    105.05   1.0        4.0      2.0
# ...                       ...    ...       ...   ...        ...      ...
# 2024-03-30 23:00:00       NaN    NaN       NaN   NaN        NaN      NaN
# 2024-03-30 23:15:00       NaN    NaN       NaN   NaN        NaN      NaN
# 2024-03-30 23:30:00       NaN    NaN       NaN   NaN        NaN      NaN
# 2024-03-30 23:45:00       NaN    NaN       NaN   NaN        NaN      NaN
# 2024-03-31 00:00:00       NaN    NaN       NaN   NaN        NaN      NaN
#
#                      month    year  dayofyear  prediction_x  prediction_y  \
# ...

# %%
df_and_future = create_features(df_and_future)
df_and_future = add_lags(df_and_future)

# %%
future_with_features = df_and_future.query('isFuture').copy()

# %%
future_with_features
# Out:
#                     Date Time  Power_MW  hour  dayofweek  quarter  month  \
# 2023-03-31 00:00:00  NaN  NaN       NaN     0          4        1      3
# 2023-03-31 00:15:00  NaN  NaN       NaN     0          4        1      3
# 2023-03-31 00:30:00  NaN  NaN       NaN     0          4        1      3
# 2023-03-31 00:45:00  NaN  NaN       NaN     0          4        1      3
# 2023-03-31 01:00:00  NaN  NaN       NaN     1          4        1      3
# ...                  ...  ...       ...   ...        ...      ...    ...
# 2024-03-30 23:00:00  NaN  NaN       NaN    23          5        1      3
# 2024-03-30 23:15:00  NaN  NaN       NaN    23          5        1      3
# 2024-03-30 23:30:00  NaN  NaN       NaN    23          5        1      3
# 2024-03-30 23:45:00  NaN  NaN       NaN    23          5        1      3
# 2024-03-31 00:00:00  NaN  NaN       NaN     0          6        1      3
#
#                      year  dayofyear  prediction_x  prediction_y  predictions  \
# ...

# %%
future_with_features['pred'] = reg.predict(future_with_features[FEATURES])

# %%
future_with_features['pred'].plot(figsize =(10,5),color ='blue',ms = 1,lw = 1, title ='FUTURE_PREDICTIONS')
plt.show()

# %%
future_with_features['pred']
# Out:
# 2023-03-31 00:00:00    119.814400
# 2023-03-31 00:15:00    119.814400
# 2023-03-31 00:30:00    119.814400
# 2023-03-31 00:45:00    119.814400
# 2023-03-31 01:00:00    119.814400
#                           ...
# 2024-03-30 23:00:00    115.182999
# 2024-03-30 23:15:00    115.182999
# 2024-03-30 23:30:00    115.182999
# 2024-03-30 23:45:00    115.182999
# 2024-03-31 00:00:00    121.949074
# Name: pred, Length: 35137, dtype: float32

# %%
future_with_features['pred'][16000:16020]
# Out:
# 2023-09-13 16:00:00     87.181778
# 2023-09-13 16:15:00     87.181778
# 2023-09-13 16:30:00     87.181778
# 2023-09-13 16:45:00     87.181778
# 2023-09-13 17:00:00     97.772293
# 2023-09-13 17:15:00     97.772293
# 2023-09-13 17:30:00     97.772293
# 2023-09-13 17:45:00     97.772293
# 2023-09-13 18:00:00    101.478035
# 2023-09-13 18:15:00    101.478035
# 2023-09-13 18:30:00    101.478035
# 2023-09-13 18:45:00    101.478035
# 2023-09-13 19:00:00    106.065369
# 2023-09-13 19:15:00    106.065369
# 2023-09-13 19:30:00    106.065369
# 2023-09-13 19:45:00    106.065369
# 2023-09-13 20:00:00    106.065369
# 2023-09-13 20:15:00    106.065369
# 2023-09-13 20:30:00    106.065369
# 2023-09-13 20:45:00    106.065369
# Name: pred, dtype: float32
